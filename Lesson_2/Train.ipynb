# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('train.csv')

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
data.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %% [raw]
# #Проверка значений DistrictId
# x=pd.Series(data['DistrictId'].unique())
# x=x.sort_values()
# x

# %%
data.drop('Healthcare_1', axis=1, inplace=True)

# %%
data.loc[data.HouseYear>2021]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 1497      6141        10            3        6       B  254084.534396
# 4189      4756        16            5        8       B  243028.603096

# %%
data.loc[data.HouseYear==20052011,'HouseYear']=2011
data.loc[data.HouseYear==4968,'HouseYear']=1968

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.273300      8.526700     12.609400   1984.866300      0.118858
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %%
lifesquare_square=(data['Square']/data['LifeSquare']).mean()
lifesquare_square
# Out:
# 2.125506539950452

# %%
data['LifeSquare']=data['LifeSquare'].fillna(data['Square']/lifesquare_square)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       10000 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     35.339113
# std     4859.01902     43.587592      0.839512     21.058732     76.832032
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     22.360510
# 50%     8394.50000     36.000000      2.000000     52.513310     31.295038
# 75%    12592.50000     75.000000      2.000000     65.900625     42.165321
# max    16798.00000    209.000000     19.000000    641.065193   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.273300      8.526700     12.609400   1984.866300      0.118858
# ...

# %%
data.loc[(data['Floor']>data['HouseFloor']),'Floor']=data.loc[(data['Floor']>data['HouseFloor']),'HouseFloor']

# %%
data.loc[data['Floor']>data['HouseFloor']]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data.loc[7]
# Out:
# Id                   11993
# DistrictId              74
# Rooms                    2
# Square             80.3129
# LifeSquare         37.7853
# KitchenSquare            0
# Floor                    0
# HouseFloor               0
# HouseYear             1977
# Ecology_1        0.0757788
# Ecology_2                B
# Ecology_3                B
# Social_1                 6
# Social_2              1437
# Social_3                 3
# Helthcare_2              0
# Shops_1                  2
# Shops_2                  B
# Price               221244
# Name: 7, dtype: object

# %%
data.loc[data['Floor']==0,'Floor']=1

# %%
data.loc[data['HouseFloor']==0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7     11993          74    2.0   80.312926   37.785311            0.0    1.0
# 23     6641          54    3.0  118.907612   55.943188            0.0    1.0
# 26     4378          27    3.0  106.958871    0.641822            0.0    1.0
# 39     9371          23    2.0   60.503248   28.465332            0.0    1.0
# 44    10521          38    3.0  104.211396  106.340403            0.0    1.0
# 65    11398          62    1.0   41.194188   19.380881            0.0    1.0
# 70    10362          27    2.0   79.227049   37.274432            0.0    1.0
# 195    4645          54    2.0   76.312851   35.903371            0.0    1.0
# 223    4622          27    2.0   62.153994   36.094352            0.0    1.0
# 252    8139          27    2.0   58.553809   27.548167            0.0    1.0
# 444    6224          59    3.0  106.349245   50.034776            0.0    1.0
# ...

# %%
data.loc[data['HouseFloor']==0,'HouseFloor']=data.loc[data['HouseFloor'],'HouseFloor'].median()

# %%
data.loc[7]
# Out:
# Id                   11993
# DistrictId              74
# Rooms                    2
# Square             80.3129
# LifeSquare         37.7853
# KitchenSquare            0
# Floor                    1
# HouseFloor              14
# HouseYear             1977
# Ecology_1        0.0757788
# Ecology_2                B
# Ecology_3                B
# Social_1                 6
# Social_2              1437
# Social_3                 3
# Helthcare_2              0
# Shops_1                  2
# Shops_2                  B
# Price               221244
# Name: 7, dtype: object

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     35.339113
# std     4859.01902     43.587592      0.839512     21.058732     76.832032
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     22.360510
# 50%     8394.50000     36.000000      2.000000     52.513310     31.295038
# 75%    12592.50000     75.000000      2.000000     65.900625     42.165321
# max    16798.00000    209.000000     19.000000    641.065193   7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.273300      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data['KitchenSquare']<=1].head()
# Out:
#        Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2    4765          53    2.0  44.947953   29.197612            0.0    8.0
# 7   11993          74    2.0  80.312926   37.785311            0.0    1.0
# 8    5172           1    2.0  64.511437   30.351089            1.0    9.0
# 12   6452          13    2.0  54.522805   31.759753            1.0    8.0
# 14  10953          27    1.0  53.769097   52.408027            1.0    4.0
#
#     HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 2         12.0       1968   0.049637         B         B        34      7759
# 7         14.0       1977   0.075779         B         B         6      1437
# 8         17.0       1977   0.007122         B         B         1       264
# 12        12.0       1999   0.090799         B         B        74     19083
# 14         4.0       1977   0.072158         B         B         2       629
#
#     Social_3  Helthcare_2  Shops_1 Shops_2          Price
# ...

# %%
#data.loc[data['KitchenSquare']<=1,'KitchenSquare']=(data.loc[data['KitchenSquare']<=1,'Square']-data.loc[data['KitchenSquare']<=1,'LifeSquare'])

# %%
data.loc[data['KitchenSquare']<=1,'KitchenSquare']=3
data.loc[2]
# Out:
# Id                    4765
# DistrictId              53
# Rooms                    2
# Square              44.948
# LifeSquare         29.1976
# KitchenSquare            3
# Floor                    8
# HouseFloor              12
# HouseYear             1968
# Ecology_1        0.0496373
# Ecology_2                B
# Ecology_3                B
# Social_1                34
# Social_2              7759
# Social_3                 0
# Helthcare_2              1
# Shops_1                  3
# Shops_2                  B
# Price               220926
# Name: 2, dtype: object

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     34.431404
# std     4859.01902     43.587592      0.839512     21.058732     18.170075
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     22.356037
# 50%     8394.50000     36.000000      2.000000     52.513310     31.277738
# 75%    12592.50000     75.000000      2.000000     65.900625     41.969903
# max    16798.00000    209.000000     19.000000    641.065193    638.163193
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.974400      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data['LifeSquare']>data['Square'],'LifeSquare'],data.loc[data['LifeSquare']>data['Square'],'Square']=data.loc[data['LifeSquare']>data['Square'],'Square'],data.loc[data['LifeSquare']>data['Square'],'LifeSquare']

# %%
data.loc[data['LifeSquare']<=data['Square']]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     14038          35    2.0   47.981561   29.442751            6.0    7.0
# 1     15053          41    3.0   65.683640   40.049543            8.0    7.0
# 2      4765          53    2.0   44.947953   29.197612            3.0    8.0
# 3      5809          58    2.0   53.352981   52.731512            9.0    8.0
# 4     10783          99    1.0   39.649192   23.776169            7.0   11.0
# 5     12915          59    3.0   80.384479   46.683720           12.0    5.0
# 6     14549         154    2.0   62.254114   37.160377            7.0    3.0
# 7     11993          74    2.0   80.312926   37.785311            3.0    1.0
# 8      5172           1    2.0   64.511437   30.351089            3.0    9.0
# 9      8649          23    1.0   46.461409   18.915552            8.0   13.0
# 10    15370          28    2.0   46.304907   27.922584            6.0    8.0
# ...

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.890500     56.315775     34.431404
# std     4859.01902     43.587592      0.839512     21.058732     18.170075
# min        0.00000      0.000000      0.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     22.356037
# 50%     8394.50000     36.000000      2.000000     52.513310     31.277738
# 75%    12592.50000     75.000000      2.000000     65.900625     41.969903
# max    16798.00000    209.000000     19.000000    641.065193    638.163193
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.974400      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data.Rooms==0]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            3.0    3.0
# 1981   7917          27    0.0  212.932361  211.231125            3.0    2.0
# 2269   7317          27    0.0   41.790881   19.661610            3.0    1.0
# 3911    770          28    0.0   49.483501   23.280804            3.0    1.0
# 4366    456           6    0.0   81.491446   38.339777            3.0    1.0
# 4853   3224          27    0.0    2.377248    0.873147            3.0    1.0
# 6149   3159          88    0.0   38.697117   19.345131            9.0    9.0
# 8834   9443          27    0.0   87.762616   85.125471            3.0    5.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
# ...

# %%
square_rooms=(data.loc[(data['Rooms']>1)&(data['Rooms']<5),'LifeSquare']/data.loc[(data['Rooms']>1)&(data['Rooms']<5),'Rooms']).median()
square_rooms
# Out:
# 15.68102378097821

# %%
data.loc[data.Rooms==0,'Rooms']=data.loc[data.Rooms==0,'LifeSquare']/square_rooms
data['Rooms']=data['Rooms'].astype(int)

# %%
data.loc[[1397,1981,2269,3911,4366,4853,6149,8834]]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27      8  138.427694  136.215499            3.0    3.0
# 1981   7917          27     13  212.932361  211.231125            3.0    2.0
# 2269   7317          27      1   41.790881   19.661610            3.0    1.0
# 3911    770          28      1   49.483501   23.280804            3.0    1.0
# 4366    456           6      2   81.491446   38.339777            3.0    1.0
# 4853   3224          27      0    2.377248    0.873147            3.0    1.0
# 6149   3159          88      1   38.697117   19.345131            9.0    9.0
# 8834   9443          27      5   87.762616   85.125471            3.0    5.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
# ...

# %%
data.loc[data.Rooms==0]
# Out:
#         Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4853  3224          27      0  2.377248    0.873147            3.0    1.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4853        14.0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 4853       469         0            0        0       B  126596.941798

# %%
data.loc[4853,['Rooms','Square','LifeSquare']]=[1,23,20]
data.loc[4853]
# Out:
# Id                    3224
# DistrictId              27
# Rooms                    1
# Square                  23
# LifeSquare              20
# KitchenSquare            3
# Floor                    1
# HouseFloor              14
# HouseYear             1977
# Ecology_1        0.0176471
# Ecology_2                B
# Ecology_3                B
# Social_1                 2
# Social_2               469
# Social_3                 0
# Helthcare_2              0
# Shops_1                  0
# Shops_2                  B
# Price               126597
# Name: 4853, dtype: object

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.889900     56.317837     34.433317
# std     4859.01902     43.587592      0.821733     21.054458     18.167548
# min        0.00000      0.000000      1.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881     22.356037
# 50%     8394.50000     36.000000      2.000000     52.513310     31.277738
# 75%    12592.50000     75.000000      2.000000     65.900625     41.969903
# max    16798.00000    209.000000     13.000000    641.065193    638.163193
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.974400      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data.Rooms>5]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27      8  138.427694  136.215499            3.0    3.0
# 1981   7917          27     13  212.932361  211.231125            3.0    2.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0       2016   0.075424         B         B        11
# 1981         3.0       2008   0.211401         B         B         9
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 1397      3097         0            0        0       B  268394.744389
# 1981      1892         0            0        1       B  302211.260887

# %%
data.loc[data.Rooms>5,'Rooms']=data.loc[data.Rooms>5,'LifeSquare']/square_rooms
data['Rooms']=data['Rooms'].astype(int)

# %%
data.loc[data.Square>300]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 4262     28           9      2  604.705972  284.499700            3.0   17.0
# 4690   2307         102      1  409.425181  409.425181           10.0    4.0
# 6977  11602          30      2  641.065193  638.163193           10.0   19.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4262        18.0       1977   0.161532         B         B        25
# 4690         4.0       2016   0.238617         B         B        26
# 6977        19.0       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 4262      5648         1            2        4       B  187717.242538
# 4690      3889         6            3        6       B   90470.430830
# 6977      6398       141            3       23       B  133529.681562

# %%
data.loc[data.Square>300,['Square','LifeSquare']]=[[data.loc[data.Square>300,'Square']/10],[data.loc[data.Square>300,'LifeSquare']/10]]

# %%
data.loc[[4262,4690,6977]]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4262     28           9      2  60.470597   28.449970            3.0   17.0
# 4690   2307         102      1  40.942518   40.942518           10.0    4.0
# 6977  11602          30      2  64.106519   63.816319           10.0   19.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4262        18.0       1977   0.161532         B         B        25
# 4690         4.0       2016   0.238617         B         B        26
# 6977        19.0       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 4262      5648         1            2        4       B  187717.242538
# 4690      3889         6            3        6       B   90470.430830
# 6977      6398       141            3       23       B  133529.681562

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.889900     56.168870     34.313429
# std     4859.01902     43.587592      0.821733     19.145689     16.533896
# min        0.00000      0.000000      1.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.773051     22.356037
# 50%     8394.50000     36.000000      2.000000     52.509275     31.275655
# 75%    12592.50000     75.000000      2.000000     65.889736     41.954393
# max    16798.00000    209.000000     13.000000    275.645284    233.949309
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.974400      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data['KitchenSquare']>40,'KitchenSquare']=data.loc[data['KitchenSquare']>40,'KitchenSquare']/10

# %%
data.loc[data['KitchenSquare']>40]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1064  14656          62      1  47.100719   46.447960          201.4    1.0
# 8584  14679          81      1  32.276663   19.278394          197.0    1.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1064         1.0       2014   0.072158         B         B         2
# 8584         1.0       1977   0.006076         B         B        30
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 1064       629         1            0        0       A  108337.484207
# 8584      5285         0            6        6       B  105539.556275

# %%
data.loc[[1064,8584],'KitchenSquare']=3

# %%
data.loc[[1064,8584]]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1064  14656          62      1  47.100719   46.447960            3.0    1.0
# 8584  14679          81      1  32.276663   19.278394            3.0    1.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1064         1.0       2014   0.072158         B         B         2
# 8584         1.0       1977   0.006076         B         B        30
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 1064       629         1            0        0       A  108337.484207
# 8584      5285         0            6        6       B  105539.556275

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.889900     56.168870     34.313429
# std     4859.01902     43.587592      0.821733     19.145689     16.533896
# min        0.00000      0.000000      1.000000      1.136859      0.370619
# 25%     4169.50000     20.000000      1.000000     41.773051     22.356037
# 50%     8394.50000     36.000000      2.000000     52.509275     31.275655
# 75%    12592.50000     75.000000      2.000000     65.889736     41.954393
# max    16798.00000    209.000000     13.000000    275.645284    233.949309
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.427290      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[(data.Square-data.LifeSquare)<data.KitchenSquare,'LifeSquare']=data.loc[(data.Square-data.LifeSquare)<data.KitchenSquare,'Square']-data.loc[(data.Square-data.LifeSquare)<data.KitchenSquare,'KitchenSquare']

# %%
data.loc[(data.Square-data.LifeSquare)<data.KitchenSquare]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 551    1315           6      1   48.128114   43.328114            4.8    1.0
# 1455  12507          54      2   79.810535   72.010535            7.8   10.0
# 2916  12390          72      3   97.490674   87.890674            9.6   22.0
# 5162  11739          27      2   61.070298   55.270298            5.8    8.0
# 7480  10546          62      1   46.013187   41.713187            4.3    4.0
# 8232   7162          34      2   56.738764   51.338764            5.4   25.0
# 9895   2737          27      3  123.430072  111.130072           12.3    5.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 551          1.0       2013   0.243205         B         B         5
# 1455        15.0       2014   0.006076         B         B        30
# 2916        25.0       2019   0.210473         B         B        11
# 5162        17.0       2016   0.072158         B         B         2
# ...

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.889900     56.168870     33.847996
# std     4859.01902     43.587592      0.821733     19.145689     15.942941
# min        0.00000      0.000000      1.000000      1.136859     -1.863141
# 25%     4169.50000     20.000000      1.000000     41.773051     22.319259
# 50%     8394.50000     36.000000      2.000000     52.509275     31.129951
# 75%    12592.50000     75.000000      2.000000     65.889736     41.244234
# max    16798.00000    209.000000     13.000000    275.645284    233.949309
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.427290      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data.Square<13]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 212    1748          88      2  5.497061    2.497061            3.0   22.0
# 1316  11526          27      1  4.633498    1.633498            3.0    1.0
# 1608  10202           6      1  2.596351   -0.403649            3.0    3.0
# 3280  10527          27      1  4.380726    1.380726            3.0   10.0
# 3413   9487           5      1  5.129222    2.129222            3.0    1.0
# 4900   4504          27      3  4.390331    1.390331            3.0    8.0
# 6392  14786           1      1  1.136859   -1.863141            3.0    1.0
# 8030  13265           1      3  4.823679    1.823679            3.0    6.0
# 8283  15744          34      1  1.988943   -1.011057            3.0    4.0
# 9294   6782          45      1  2.954309   -0.045691            3.0    1.0
# 9613   7657          38      1  4.502784    1.502784            3.0    1.0
#
# ...

# %%
data.loc[data.Square<13,'Square']=data.loc[data.Square<13,'Square']*10

# %%
data.loc[data.Square<13]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6392  14786           1      1  11.368588   -1.863141            3.0    1.0
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6392         1.0       1977   0.007122         B         B         1
#
#       Social_2  Social_3  Helthcare_2  Shops_1 Shops_2          Price
# 6392       264         0            0        1       B  181434.825589

# %%
data.loc[6392,'Square']=15

# %%
data.loc[data.LifeSquare<2]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 363   15751           9      1   44.171793    1.251846            3.0   11.0
# 674   10631          88      1   42.571618    1.941521            3.0    1.0
# 683   15091          27      2   66.535842    1.638083            3.0    1.0
# 707    4345          62      1   49.275155    1.377284            3.0    1.0
# 751   11989          62      3  104.446306    1.451067            3.0   12.0
# 850    2470           6      1   43.312025    1.404493            3.0   11.0
# 1316  11526          27      1   46.334984    1.633498            3.0    1.0
# 1580    363          27      2   59.715762    1.595943            3.0    1.0
# 1827  16176           6      2   64.998310    1.974968            3.0   13.0
# 2142  15261          22      3   83.162217    1.318250            3.0    1.0
# 2224   3746          62      1   46.722042    1.944446            3.0   11.0
# ...

# %%
data.loc[data.LifeSquare<0,'LifeSquare']=data.loc[data.LifeSquare<0,'LifeSquare']*(-1)

# %%
data.loc[data.LifeSquare<2,'LifeSquare']=data.loc[data.LifeSquare<2,'LifeSquare']*10

# %%
data.loc[9294,'LifeSquare']=20

# %%
data.loc[data.LifeSquare<2]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data.describe()
# Out:
#                 Id    DistrictId         Rooms        Square    LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  10000.000000
# mean    8383.40770     50.400800      1.889900     56.207063     34.299327
# std     4859.01902     43.587592      0.821733     19.080457     15.453037
# min        0.00000      0.000000      1.000000     13.784865     10.110573
# 25%     4169.50000     20.000000      1.000000     41.784346     22.481556
# 50%     8394.50000     36.000000      2.000000     52.513310     31.331103
# 75%    12592.50000     75.000000      2.000000     65.889736     41.463731
# max    16798.00000    209.000000     13.000000    275.645284    233.949309
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        6.427290      7.727300     12.986000   1984.866300      0.118858
# ...

# %%
data.loc[data.LifeSquare<10,'LifeSquare']=data.loc[data.LifeSquare<10,'Rooms']*square_rooms

# %%
data.loc[data.LifeSquare<10]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []
